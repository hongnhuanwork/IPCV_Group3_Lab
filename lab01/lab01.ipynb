# %%
import cv2

# %%
img = cv2.imread("lab01.jpg")

# Hiển thị ảnh
cv2.imshow("Image",img)

cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# QFontDatabase: Cannot find font directory /media/hvandien/Acer/Users/hoang/Documents/Minh Huy Group/Selenium Test/py312/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /media/hvandien/Acer/Users/hoang/Documents/Minh Huy Group/Selenium Test/py312/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /media/hvandien/Acer/Users/hoang/Documents/Minh Huy Group/Selenium Test/py312/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ...

# %%
cv2.imwrite("lab01_copy.png", img)
# Out:
# True

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Image", gray)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2.imshow("HSV Image", hsv)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
cv2.imshow("LAB Image", lab)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
crop = img[100:300, 200:400]

cv2.imshow("Crop Image", crop)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
resize = cv2.resize(img, (400, 300))
cv2.imshow("Resize Image", resize)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
resize = cv2.resize(img, None, fx=0.2, fy=0.2)
cv2.imshow("Resize 20%", resize)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
cv2.line(resize, (50,50), (300,50), (0,255,0), 3)

cv2.rectangle(resize, (50,100), (300,200), (255,0,0), 2)

cv2.circle(resize, (200,200), 50, (0,0,255), 3)
# Out:
# array([[[ 55, 106,  78],
#         [ 54, 108,  79],
#         [ 42, 102,  72],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 55, 114,  83],
#         [ 56, 116,  85],
#         [ 50, 113,  81],
#         ...,
#         [253, 255, 254],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[ 56, 117,  83],
#         [ 57, 118,  84],
#         [ 51, 117,  82],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[172, 172, 212],
#         [172, 172, 212],
#         [171, 171, 211],
#         ...,
#         [154, 158, 169],
#         [156, 158, 168],
#         [155, 157, 167]],
#
#        [[171, 171, 211],
#         [171, 171, 211],
#         [171, 170, 212],
#         ...,
#         [153, 159, 170],
#         [152, 158, 169],
#         [152, 156, 167]],
#
#        [[171, 171, 211],
#         [171, 171, 211],
#         [171, 170, 212],
# ...

# %%
cv2.putText(resize,
            "Hoang Van Dien",
            (50,50),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (255,255,255),
            2)

cv2.imshow("Image with Text", resize)
cv2.waitKey(5000)
cv2.destroyAllWindows()
